# %%
import pandas as pd
import random

# Read data from the downloaded CSV file
data = pd.read_csv('https://s3-eu-west-1.amazonaws.com/shanebucket/downloads/uk-500.csv')
# set a numeric id for use as an index for examples.
data['id'] = [random.randint(0,1000) for x in range(data.shape[0])]
 
data.head(5)
# Out:
#   first_name   last_name             company_name            address  \
# 0    Aleshia  Tomkiewicz  Alan D Rosenburg Cpa Pc       14 Taylor St
# 1       Evan   Zigomalas       Cap Gemini America        5 Binney St
# 2     France     Andrade      Elliott, John W Esq       8 Moor Place
# 3    Ulysses   Mcwalters           Mcmahan, Ben L      505 Exeter Rd
# 4     Tyisha      Veness           Champagne Room  5396 Forth Street
#
#                              city           county    postal        phone1  \
# 0               St. Stephens Ward             Kent   CT2 7PP  01835-703597
# 1                      Abbey Ward  Buckinghamshire  HP11 2AX  01937-864715
# 2  East Southbourne and Tuckton W      Bournemouth   BH6 3BE  01347-368222
# 3              Hawerby cum Beesby     Lincolnshire  DN36 5RP  01912-771311
# 4      Greets Green and Lyng Ward    West Midlands   B70 9DT  01547-429341
#
#          phone2                       email  \
# 0  01944-369967     atomkiewicz@hotmail.com
# 1  01714-737668    evan.zigomalas@gmail.com
# 2  01935-821636  france.andrade@hotmail.com
# 3  01302-601380         ulysses@hotmail.com
# 4  01290-367248   tyisha.veness@hotmail.com
#
#                                     web   id
# 0  http://www.alandrosenburgcpapc.co.uk  991
# 1     http://www.capgeminiamerica.co.uk   80
# 2      http://www.elliottjohnwesq.co.uk   15
# 3          http://www.mcmahanbenl.co.uk  493
# 4        http://www.champagneroom.co.uk   76

# %%
# selecting pandas data using iloc
# Single selections using iloc and DataFrame
# Rows:
data.iloc[0] # first row of data frame (Aleshia Tomkiewicz) - Note a Series data type output.
# Out:
# first_name                                   Aleshia
# last_name                                 Tomkiewicz
# company_name                 Alan D Rosenburg Cpa Pc
# address                                 14 Taylor St
# city                               St. Stephens Ward
# county                                          Kent
# postal                                       CT2 7PP
# phone1                                  01835-703597
# phone2                                  01944-369967
# email                        atomkiewicz@hotmail.com
# web             http://www.alandrosenburgcpapc.co.uk
# id                                               991
# Name: 0, dtype: object

# %%
data.iloc[1] # second row of data frame (Evan Zigomalas)
# Out:
# first_name                                   Evan
# last_name                               Zigomalas
# company_name                   Cap Gemini America
# address                               5 Binney St
# city                                   Abbey Ward
# county                            Buckinghamshire
# postal                                   HP11 2AX
# phone1                               01937-864715
# phone2                               01714-737668
# email                    evan.zigomalas@gmail.com
# web             http://www.capgeminiamerica.co.uk
# id                                             80
# Name: 1, dtype: object

# %%
data.iloc[-1] # last row of data frame (Mi Richan)
# Out:
# first_name                                               Mi
# last_name                                            Richan
# company_name                 Nelson Wright Haworth Golf Crs
# address                                     6 Norwood Grove
# city                                      Tanworth-in-Arden
# county                                         Warwickshire
# postal                                              B94 5RZ
# phone1                                         01451-785624
# phone2                                         01202-738406
# email                                        mi@hotmail.com
# web             http://www.nelsonwrighthaworthgolfcrs.co.uk
# id                                                      500
# Name: 499, dtype: object

# %%
# columns
data.iloc[:,0] # first column of data frame (first_name)
# Out:
# 0          Aleshia
# 1             Evan
# 2           France
# 3          Ulysses
# 4           Tyisha
# 5             Eric
# 6             Marg
# 7          Laquita
# 8             Lura
# 9           Yuette
# 10        Fernanda
# 11     Charlesetta
# 12        Corrinne
# 13          Niesha
# 14          Rueben
# 15         Michell
# 16           Edgar
# 17          Dewitt
# 18        Charisse
# 19             Mee
# 20           Peter
# 21         Octavio
# 22          Martha
# 23         Tamesha
# 24            Tess
# 25         Leonard
# 26        Svetlana
# 27             Pok
# 28       Augustine
# 29           Karma
#           ...
# 470           Tony
# 471            Val
# 472            Mel
# 473       Isabella
# 474         Erasmo
# 475          Ivory
# 476         Nikita
# 477          Aleta
# 478           Owen
# 479        Pauline
# 480        Tijuana
# 481          Ahmad
# 482         Jamika
# 483        Derrick
# 484     Jacquelyne
# 485        Zachary
# 486         Sophia
# 487       Isabelle
# 488         Ronnie
# 489       Krystina
# 490         Rosita
# 491           Huey
# 492         Elbert
# 493           Pura
# 494         Alesia
# 495          Avery
# 496           Reid
# 497      Charlette
# 498      Celestina
# 499             Mi
# Name: first_name, Length: 500, dtype: object

# %%
data.iloc[:,1] # second column of data frame (last_name)
# Out:
# 0      Tomkiewicz
# 1       Zigomalas
# 2         Andrade
# 3       Mcwalters
# 4          Veness
# 5           Rampy
# 6        Grasmick
# 7           Hisaw
# 8        Manzella
# 9          Klapec
# 10         Writer
# 11            Erm
# 12          Jaret
# 13          Bruch
# 14      Gastellum
# 15      Throssell
# 16          Kanne
# 17          Julio
# 18       Spinello
# 19       Lapinski
# 20      Gutierres
# 21      Salvadore
# 22        Teplica
# 23         Veigel
# 24          Sitra
# 25         Kufner
# 26         Tauras
# 27       Molaison
# 28       Growcock
# 29         Quarto
#           ...
# 470    Diazdeleon
# 471        Villot
# 472      Picciuto
# 473    Piatkowski
# 474          Rhea
# 475       Lohrenz
# 476         Walka
# 477        Ligons
# 478       Jentzen
# 479         Fling
# 480      Machalek
# 481       Alsaqri
# 482        Conoly
# 483       Dolloff
# 484       Reibman
# 485    Freeburger
# 486       Gaucher
# 487          Kono
# 488       Brigman
# 489    Schlabaugh
# 490     Ausdemore
# 491       Stancil
# 492       Fiorino
# 493       Manciel
# 494         Katie
# 495          Veit
# 496       Euresti
# 497      Brenning
# 498         Keeny
# 499        Richan
# Name: last_name, Length: 500, dtype: object

# %%
data.iloc[:,-1] # last column of data frame (id)
# Out:
# 0      991
# 1       80
# 2       15
# 3      493
# 4       76
# 5      342
# 6      169
# 7      332
# 8      991
# 9      368
# 10     790
# 11     178
# 12     336
# 13     490
# 14     731
# 15     436
# 16     797
# 17     415
# 18     556
# 19     922
# 20     698
# 21     540
# 22     273
# 23     722
# 24     769
# 25     354
# 26     854
# 27      46
# 28     798
# 29     222
#       ...
# 470    430
# 471    902
# 472     83
# 473    451
# 474     36
# 475     31
# 476    712
# 477    353
# 478    589
# 479    505
# 480    464
# 481    112
# 482    638
# 483     79
# 484     35
# 485    354
# 486    743
# 487    665
# 488    501
# 489     82
# 490    311
# 491    248
# 492    177
# 493    578
# 494    570
# 495    317
# 496    681
# 497    851
# 498    674
# 499    500
# Name: id, Length: 500, dtype: int64

# %%
# Multiple row and column selections using iloc and DataFrame
data.iloc[0:5] # first five rows of dataframe
# Out:
#   first_name   last_name             company_name            address  \
# 0    Aleshia  Tomkiewicz  Alan D Rosenburg Cpa Pc       14 Taylor St
# 1       Evan   Zigomalas       Cap Gemini America        5 Binney St
# 2     France     Andrade      Elliott, John W Esq       8 Moor Place
# 3    Ulysses   Mcwalters           Mcmahan, Ben L      505 Exeter Rd
# 4     Tyisha      Veness           Champagne Room  5396 Forth Street
#
#                              city           county    postal        phone1  \
# 0               St. Stephens Ward             Kent   CT2 7PP  01835-703597
# 1                      Abbey Ward  Buckinghamshire  HP11 2AX  01937-864715
# 2  East Southbourne and Tuckton W      Bournemouth   BH6 3BE  01347-368222
# 3              Hawerby cum Beesby     Lincolnshire  DN36 5RP  01912-771311
# 4      Greets Green and Lyng Ward    West Midlands   B70 9DT  01547-429341
#
#          phone2                       email  \
# 0  01944-369967     atomkiewicz@hotmail.com
# 1  01714-737668    evan.zigomalas@gmail.com
# 2  01935-821636  france.andrade@hotmail.com
# 3  01302-601380         ulysses@hotmail.com
# 4  01290-367248   tyisha.veness@hotmail.com
#
#                                     web   id
# 0  http://www.alandrosenburgcpapc.co.uk  991
# 1     http://www.capgeminiamerica.co.uk   80
# 2      http://www.elliottjohnwesq.co.uk   15
# 3          http://www.mcmahanbenl.co.uk  493
# 4        http://www.champagneroom.co.uk   76

# %%
data.iloc[:, 0:2] # first two columns of data frame with all rows
# Out:
#       first_name   last_name
# 0        Aleshia  Tomkiewicz
# 1           Evan   Zigomalas
# 2         France     Andrade
# 3        Ulysses   Mcwalters
# 4         Tyisha      Veness
# 5           Eric       Rampy
# 6           Marg    Grasmick
# 7        Laquita       Hisaw
# 8           Lura    Manzella
# 9         Yuette      Klapec
# 10      Fernanda      Writer
# 11   Charlesetta         Erm
# 12      Corrinne       Jaret
# 13        Niesha       Bruch
# 14        Rueben   Gastellum
# 15       Michell   Throssell
# 16         Edgar       Kanne
# 17        Dewitt       Julio
# 18      Charisse    Spinello
# 19           Mee    Lapinski
# 20         Peter   Gutierres
# 21       Octavio   Salvadore
# 22        Martha     Teplica
# 23       Tamesha      Veigel
# 24          Tess       Sitra
# 25       Leonard      Kufner
# 26      Svetlana      Tauras
# 27           Pok    Molaison
# 28     Augustine    Growcock
# 29         Karma      Quarto
# ..           ...         ...
# 470         Tony  Diazdeleon
# 471          Val      Villot
# 472          Mel    Picciuto
# 473     Isabella  Piatkowski
# 474       Erasmo        Rhea
# 475        Ivory     Lohrenz
# 476       Nikita       Walka
# 477        Aleta      Ligons
# 478         Owen     Jentzen
# 479      Pauline       Fling
# 480      Tijuana    Machalek
# 481        Ahmad     Alsaqri
# 482       Jamika      Conoly
# 483      Derrick     Dolloff
# 484   Jacquelyne     Reibman
# 485      Zachary  Freeburger
# 486       Sophia     Gaucher
# 487     Isabelle        Kono
# 488       Ronnie     Brigman
# 489     Krystina  Schlabaugh
# 490       Rosita   Ausdemore
# 491         Huey     Stancil
# 492       Elbert     Fiorino
# 493         Pura     Manciel
# 494       Alesia       Katie
# 495        Avery        Veit
# 496         Reid     Euresti
# 497    Charlette    Brenning
# 498    Celestina       Keeny
# 499           Mi      Richan
#
# [500 rows x 2 columns]

# %%
data.iloc[[0,3,6,24], [0,5,6]] # 1st, 4th, 7th, 25th row + 1st 6th 7th columns.
# Out:
#    first_name        county    postal
# 0     Aleshia          Kent   CT2 7PP
# 3     Ulysses  Lincolnshire  DN36 5RP
# 6        Marg   Southampton  SO14 3TY
# 24       Tess   West Sussex  PO19 1RH

# %%
data.iloc[0:5, 5:8] # first 5 rows and 5th, 6th, 7th columns of data frame (county -> phone1).
# Out:
#             county    postal        phone1
# 0             Kent   CT2 7PP  01835-703597
# 1  Buckinghamshire  HP11 2AX  01937-864715
# 2      Bournemouth   BH6 3BE  01347-368222
# 3     Lincolnshire  DN36 5RP  01912-771311
# 4    West Midlands   B70 9DT  01547-429341

# %%
# The Pandas loc indexer can be used with DataFrames for two different use cases:
# a.) Selecting rows by label/index
# b.) Selecting rows with a boolean / conditional lookup
data.set_index("last_name", inplace=True)
data.head()
# Out:
#            first_name             company_name            address  \
# last_name
# Tomkiewicz    Aleshia  Alan D Rosenburg Cpa Pc       14 Taylor St
# Zigomalas        Evan       Cap Gemini America        5 Binney St
# Andrade        France      Elliott, John W Esq       8 Moor Place
# Mcwalters     Ulysses           Mcmahan, Ben L      505 Exeter Rd
# Veness         Tyisha           Champagne Room  5396 Forth Street
#
#                                       city           county    postal  \
# last_name
# Tomkiewicz               St. Stephens Ward             Kent   CT2 7PP
# Zigomalas                       Abbey Ward  Buckinghamshire  HP11 2AX
# Andrade     East Southbourne and Tuckton W      Bournemouth   BH6 3BE
# Mcwalters               Hawerby cum Beesby     Lincolnshire  DN36 5RP
# Veness          Greets Green and Lyng Ward    West Midlands   B70 9DT
#
#                   phone1        phone2                       email  \
# last_name
# Tomkiewicz  01835-703597  01944-369967     atomkiewicz@hotmail.com
# Zigomalas   01937-864715  01714-737668    evan.zigomalas@gmail.com
# Andrade     01347-368222  01935-821636  france.andrade@hotmail.com
# Mcwalters   01912-771311  01302-601380         ulysses@hotmail.com
# Veness      01547-429341  01290-367248   tyisha.veness@hotmail.com
#
#                                              web   id
# last_name
# Tomkiewicz  http://www.alandrosenburgcpapc.co.uk  991
# Zigomalas      http://www.capgeminiamerica.co.uk   80
# Andrade         http://www.elliottjohnwesq.co.uk   15
# Mcwalters           http://www.mcmahanbenl.co.uk  493
# Veness            http://www.champagneroom.co.uk   76

# %%
data.loc['Andrade']
# Out:
# first_name                                France
# company_name                 Elliott, John W Esq
# address                             8 Moor Place
# city              East Southbourne and Tuckton W
# county                               Bournemouth
# postal                                   BH6 3BE
# phone1                              01347-368222
# phone2                              01935-821636
# email                 france.andrade@hotmail.com
# web             http://www.elliottjohnwesq.co.uk
# id                                            15
# Name: Andrade, dtype: object

# %%
data.loc[['Andrade','Veness']]
# Out:
#           first_name         company_name            address  \
# last_name
# Andrade       France  Elliott, John W Esq       8 Moor Place
# Veness        Tyisha       Champagne Room  5396 Forth Street
#
#                                      city         county   postal  \
# last_name
# Andrade    East Southbourne and Tuckton W    Bournemouth  BH6 3BE
# Veness         Greets Green and Lyng Ward  West Midlands  B70 9DT
#
#                  phone1        phone2                       email  \
# last_name
# Andrade    01347-368222  01935-821636  france.andrade@hotmail.com
# Veness     01547-429341  01290-367248   tyisha.veness@hotmail.com
#
#                                         web  id
# last_name
# Andrade    http://www.elliottjohnwesq.co.uk  15
# Veness       http://www.champagneroom.co.uk  76

# %%
data.loc[['Andrade','Veness'],['first_name', 'address','city']]
# Out:
#           first_name            address                            city
# last_name
# Andrade       France       8 Moor Place  East Southbourne and Tuckton W
# Veness        Tyisha  5396 Forth Street      Greets Green and Lyng Ward

# %%
# Select rows with index values 'Andrade' and 'Veness', with all columns between 'city' and 'email'
data.loc[['Andrade', 'Veness'], 'city':'email']
# Out:
#                                      city         county   postal  \
# last_name
# Andrade    East Southbourne and Tuckton W    Bournemouth  BH6 3BE
# Veness         Greets Green and Lyng Ward  West Midlands  B70 9DT
#
#                  phone1        phone2                       email
# last_name
# Andrade    01347-368222  01935-821636  france.andrade@hotmail.com
# Veness     01547-429341  01290-367248   tyisha.veness@hotmail.com

# %%
# Select same rows, with just 'first_name', 'address' and 'city' columns
data.loc['Andrade':'Veness', ['first_name', 'address', 'city']]
# Out:
#           first_name            address                            city
# last_name
# Andrade       France       8 Moor Place  East Southbourne and Tuckton W
# Mcwalters    Ulysses      505 Exeter Rd              Hawerby cum Beesby
# Veness        Tyisha  5396 Forth Street      Greets Green and Lyng Ward

# %%
data.loc[data['first_name']=='Antonio']
# Out:
#     first_name            company_name                address  \
# id
# 945    Antonio        Combs Sheetmetal  353 Standish St #8264
# 678    Antonio  Saint Thomas Creations          425 Howley St
# 517    Antonio    Radisson Suite Hotel         35 Elton St #3
#
#                                city         county    postal        phone1  \
# id
# 945  Little Parndon and Hare Street  Hertfordshire  CM20 2HT  01559-403415
# 678                  Gaer Community        Newport  NP20 3DE  01463-409090
# 517                        Ipplepen          Devon  TQ12 5LL  01324-171614
#
#            phone2                            email  \
# id
# 945  01388-777812     antonio.villamarin@gmail.com
# 678  01242-318420  antonio_glasford@glasford.co.uk
# 517  01442-946357         antonio.heilig@gmail.com
#
#                                        web
# id
# 945       http://www.combssheetmetal.co.uk
# 678  http://www.saintthomascreations.co.uk
# 517    http://www.radissonsuitehotel.co.uk

# %%
data.loc[data['first_name']=='Erasmo',['first_name','company_name','email','phone1']]
# Out:
#     first_name        company_name                         email        phone1
# id
# 220     Erasmo  Active Air Systems  erasmo.talentino@hotmail.com  01492-454455
# 428     Erasmo            Pan Optx             egath@hotmail.com  01445-796544
# 36      Erasmo    Martin Morrissey       erasmo_rhea@hotmail.com  01507-386397

# %%
# Reference: https://www.shanelynn.ie/select-pandas-dataframe-rows-and-columns-using-iloc-loc-and-ix/
